# %%
import pandas as pd
import seaborn as sns
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print("hello")
# Out:
# hello

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
print(tips.info())
print(tips.shape)
print(tips.time.unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.2 KB
# None
# (244, 7)
# [Dinner, Lunch]
# Categories (2, object): [Dinner, Lunch]

# %%
tips.groupby(["time","sex","day"])["tip"].agg(["sum","mean","count"])
# Out:
#                        sum      mean  count
# time   sex    day
# Lunch  Male   Thur   89.41  2.980333     30
#               Fri     5.70  1.900000      3
#        Female Thur   79.42  2.561935     31
#               Fri    10.98  2.745000      4
# Dinner Male   Fri    21.23  3.032857      7
#               Sat   181.95  3.083898     59
#               Sun   186.78  3.220345     58
#        Female Thur    3.00  3.000000      1
#               Fri    14.05  2.810000      5
#               Sat    78.45  2.801786     28
#               Sun    60.61  3.367222     18

# %%
tips[(tips.time=="Lunch")]["tip"].sum()
# Out:
# 185.51000000000002

# %%
tips[(tips.time=="Dinner")]["tip"].mean()
# Out:
# 3.102670454545454

# %%
tips.groupby(["time","sex","day"])["tip"].agg(["sum","mean","count"])
# Out:
#                        sum      mean  count
# time   sex    day
# Lunch  Male   Thur   89.41  2.980333     30
#               Fri     5.70  1.900000      3
#        Female Thur   79.42  2.561935     31
#               Fri    10.98  2.745000      4
# Dinner Male   Fri    21.23  3.032857      7
#               Sat   181.95  3.083898     59
#               Sun   186.78  3.220345     58
#        Female Thur    3.00  3.000000      1
#               Fri    14.05  2.810000      5
#               Sat    78.45  2.801786     28
#               Sun    60.61  3.367222     18

# %%
tips.set_index(["sex"]).head()
# Out:
#         total_bill   tip smoker  day    time  size
# sex
# Female       16.99  1.01     No  Sun  Dinner     2
# Male         10.34  1.66     No  Sun  Dinner     3
# Male         21.01  3.50     No  Sun  Dinner     3
# Male         23.68  3.31     No  Sun  Dinner     2
# Female       24.59  3.61     No  Sun  Dinner     4

# %%
multi_index=tips.set_index(["sex","size"])
multi_index
# Out:
#              total_bill   tip smoker   day    time
# sex    size
# Female 2          16.99  1.01     No   Sun  Dinner
# Male   3          10.34  1.66     No   Sun  Dinner
#        3          21.01  3.50     No   Sun  Dinner
#        2          23.68  3.31     No   Sun  Dinner
# Female 4          24.59  3.61     No   Sun  Dinner
# Male   4          25.29  4.71     No   Sun  Dinner
#        2           8.77  2.00     No   Sun  Dinner
#        4          26.88  3.12     No   Sun  Dinner
#        2          15.04  1.96     No   Sun  Dinner
#        2          14.78  3.23     No   Sun  Dinner
#        2          10.27  1.71     No   Sun  Dinner
# Female 4          35.26  5.00     No   Sun  Dinner
# Male   2          15.42  1.57     No   Sun  Dinner
#        4          18.43  3.00     No   Sun  Dinner
# Female 2          14.83  3.02     No   Sun  Dinner
# Male   2          21.58  3.92     No   Sun  Dinner
# Female 3          10.33  1.67     No   Sun  Dinner
# ...

# %%
multi_index.sort_index(inplace=True)

# %%
multi_index.head()
# Out:
#            total_bill   tip smoker  day    time
# sex  size
# Male 1           8.58  1.92    Yes  Fri   Lunch
#      2          23.68  3.31     No  Sun  Dinner
#      2           8.77  2.00     No  Sun  Dinner
#      2          15.04  1.96     No  Sun  Dinner
#      2          14.78  3.23     No  Sun  Dinner

# %%
multi_index.loc["Male"]
# Out:
#       total_bill   tip smoker   day    time
# size
# 1           8.58  1.92    Yes   Fri   Lunch
# 2          23.68  3.31     No   Sun  Dinner
# 2           8.77  2.00     No   Sun  Dinner
# 2          15.04  1.96     No   Sun  Dinner
# 2          14.78  3.23     No   Sun  Dinner
# 2          10.27  1.71     No   Sun  Dinner
# 2          15.42  1.57     No   Sun  Dinner
# 2          21.58  3.92     No   Sun  Dinner
# 2          17.92  4.08     No   Sat  Dinner
# 2          19.82  3.18     No   Sat  Dinner
# 2          13.37  2.00     No   Sat  Dinner
# 2          12.69  2.00     No   Sat  Dinner
# 2          21.70  4.30     No   Sat  Dinner
# 2           9.55  1.45     No   Sat  Dinner
# 2          17.78  3.27     No   Sat  Dinner
# 2          17.46  2.54     No   Sun  Dinner
# 2          13.94  3.06     No   Sun  Dinner
# 2           9.68  1.32     No   Sun  Dinner
# 2          18.29  3.00     No   Sun  Dinner
# 2          22.23  5.00     No   Sun  Dinner
# ...

# %%
multi_index.xs(2,level="size").head()
# Out:
#       total_bill   tip smoker  day    time
# sex
# Male       23.68  3.31     No  Sun  Dinner
# Male        8.77  2.00     No  Sun  Dinner
# Male       15.04  1.96     No  Sun  Dinner
# Male       14.78  3.23     No  Sun  Dinner
# Male       10.27  1.71     No  Sun  Dinner

# %%
tips.groupby("time").sum()
# Out:
#         total_bill     tip  size
# time
# Lunch      1167.47  185.51   164
# Dinner     3660.30  546.07   463

# %%
tips["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
tips["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
people=[["veer",35,"ab+ve"],["khusbu",32,"b+ve"],["srija",4,"ab+ve"],["bittu",34,"o+ve"]]
people_df=pd.DataFrame(people,columns=["name","age","blood group"])
people_df
# Out:
#      name  age blood group
# 0    veer   35       ab+ve
# 1  khusbu   32        b+ve
# 2   srija    4       ab+ve
# 3   bittu   34        o+ve

# %%
people_new_df=people_df["age"].apply(lambda x:x*2)
people_new_df
# Out:
# 0    70
# 1    64
# 2     8
# 3    68
# Name: age, dtype: int64

# %%
def double(x):
    if x%2==0:
        return x*2

# %%
people_df["age"].apply(double)
# Out:
# 0     NaN
# 1    64.0
# 2     8.0
# 3    68.0
# Name: age, dtype: float64

# %%
tips[(tips.time=="Dinner")]["tip"].sum()
# Out:
# 546.0699999999999

# %%
import pandas as pd
air_df = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/AirQualityUCI.csv')
air_df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6         1360       150      11.9
# 1  3/10/2004  19:00:00     2.0         1292       112       9.4
# 2  3/10/2004  20:00:00     2.2         1402        88       9.0
# 3  3/10/2004  21:00:00     2.2         1376        80       9.2
# 4  3/10/2004  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
air_df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
# Date             9357 non-null object
# Time             9357 non-null object
# CO(GT)           9357 non-null float64
# PT08.S1(CO)      9357 non-null int64
# NMHC(GT)         9357 non-null int64
# C6H6(GT)         9357 non-null float64
# PT08.S2(NMHC)    9357 non-null int64
# NOx(GT)          9357 non-null int64
# PT08.S3(NOx)     9357 non-null int64
# NO2(GT)          9357 non-null int64
# PT08.S4(NO2)     9357 non-null int64
# PT08.S5(O3)      9357 non-null int64
# T                9357 non-null float64
# RH               9357 non-null float64
# AH               9357 non-null float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 1.1+ MB

# %%
air_df[air_df["NMHC(GT)"]==-200]["NMHC(GT)"].count()
# Out:
# 8443

# %%
air_df.drop(["NMHC(GT)"],axis=1)
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  C6H6(GT)  PT08.S2(NMHC)  \
# 0     3/10/2004  18:00:00     2.6         1360      11.9           1046
# 1     3/10/2004  19:00:00     2.0         1292       9.4            955
# 2     3/10/2004  20:00:00     2.2         1402       9.0            939
# 3     3/10/2004  21:00:00     2.2         1376       9.2            948
# 4     3/10/2004  22:00:00     1.6         1272       6.5            836
# 5     3/10/2004  23:00:00     1.2         1197       4.7            750
# 6     3/11/2004   0:00:00     1.2         1185       3.6            690
# 7     3/11/2004   1:00:00     1.0         1136       3.3            672
# 8     3/11/2004   2:00:00     0.9         1094       2.3            609
# 9     3/11/2004   3:00:00     0.6         1010       1.7            561
# 10    3/11/2004   4:00:00  -200.0         1011       1.3            527
# 11    3/11/2004   5:00:00     0.7         1066       1.1            512
# ...

# %%
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
# Date             9357 non-null object
# Time             9357 non-null object
# CO(GT)           9357 non-null float64
# PT08.S1(CO)      9357 non-null int64
# NMHC(GT)         9357 non-null int64
# C6H6(GT)         9357 non-null float64
# PT08.S2(NMHC)    9357 non-null int64
# NOx(GT)          9357 non-null int64
# PT08.S3(NOx)     9357 non-null int64
# NO2(GT)          9357 non-null int64
# PT08.S4(NO2)     9357 non-null int64
# PT08.S5(O3)      9357 non-null int64
# T                9357 non-null float64
# RH               9357 non-null float64
# AH               9357 non-null float64
# dtypes: float64(5), int64(8), object(2)
# memory usage: 1.1+ MB

# %%
air_df["Date"]=pd.to_datetime(air_df["Date"],format="%m/%d/%Y")
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
# Date             9357 non-null datetime64[ns]
# Time             9357 non-null object
# CO(GT)           9357 non-null float64
# PT08.S1(CO)      9357 non-null int64
# NMHC(GT)         9357 non-null int64
# C6H6(GT)         9357 non-null float64
# PT08.S2(NMHC)    9357 non-null int64
# NOx(GT)          9357 non-null int64
# PT08.S3(NOx)     9357 non-null int64
# NO2(GT)          9357 non-null int64
# PT08.S4(NO2)     9357 non-null int64
# PT08.S5(O3)      9357 non-null int64
# T                9357 non-null float64
# RH               9357 non-null float64
# AH               9357 non-null float64
# dtypes: datetime64[ns](1), float64(5), int64(8), object(1)
# memory usage: 1.1+ MB

# %%
air_df["Time"]=pd.to_datetime(air_df["Time"],format="%H:%M:%S")
air_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 15 columns):
# Date             9357 non-null datetime64[ns]
# Time             9357 non-null datetime64[ns]
# CO(GT)           9357 non-null float64
# PT08.S1(CO)      9357 non-null int64
# NMHC(GT)         9357 non-null int64
# C6H6(GT)         9357 non-null float64
# PT08.S2(NMHC)    9357 non-null int64
# NOx(GT)          9357 non-null int64
# PT08.S3(NOx)     9357 non-null int64
# NO2(GT)          9357 non-null int64
# PT08.S4(NO2)     9357 non-null int64
# PT08.S5(O3)      9357 non-null int64
# T                9357 non-null float64
# RH               9357 non-null float64
# AH               9357 non-null float64
# dtypes: datetime64[ns](2), float64(5), int64(8)
# memory usage: 1.1 MB

# %%
air_df["Date"]=pd.to_datetime(air_df["Date"],format="%m/%d/%Y")
air_df["Time"]=pd.to_datetime(air_df["Time"],format="%H:%M:%S")

# %%
year=air_df["Date"].dt.year
year.head()
# Out:
# 0    2004
# 1    2004
# 2    2004
# 3    2004
# 4    2004
# Name: Date, dtype: int64

# %%
month=air_df["Date"].dt.month
month.head()
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# 4    3
# Name: Date, dtype: int64

# %%
day=air_df["Date"].dt.day
day.head()
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# 4    10
# Name: Date, dtype: int64

# %%
day.nunique()
# Out:
# 31

# %%
month.nunique()
# Out:
# 12

# %%
day_week=air_df["Date"].dt.dayofweek
day_week.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Date, dtype: int64

# %%
air_df[air_df["NMHC(GT)"]==-200][air_df["NMHC(GT)"]].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-1ec84ab74f98> in <module>
# ----> 1 air_df[air_df["NMHC(GT)"]==-200][air_df["NMHC(GT)"]].count()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# ...

# %%
air_df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
air_df[air_df["NMHC(GT)"]==-200]["NMHC(GT)"].count()
# Out:
# 8443

# %%
air_df[air_df["NMHC(GT)"]==-200]["NMHC(GT)"].count()
# Out:
# 8443

# %%
air_df
# Out:
#            Date                Time  CO(GT)  PT08.S1(CO)  C6H6(GT)  \
# 0    2004-03-10 1900-01-01 18:00:00     2.6         1360      11.9
# 1    2004-03-10 1900-01-01 19:00:00     2.0         1292       9.4
# 2    2004-03-10 1900-01-01 20:00:00     2.2         1402       9.0
# 3    2004-03-10 1900-01-01 21:00:00     2.2         1376       9.2
# 4    2004-03-10 1900-01-01 22:00:00     1.6         1272       6.5
# 5    2004-03-10 1900-01-01 23:00:00     1.2         1197       4.7
# 6    2004-03-11 1900-01-01 00:00:00     1.2         1185       3.6
# 7    2004-03-11 1900-01-01 01:00:00     1.0         1136       3.3
# 8    2004-03-11 1900-01-01 02:00:00     0.9         1094       2.3
# 9    2004-03-11 1900-01-01 03:00:00     0.6         1010       1.7
# 10   2004-03-11 1900-01-01 04:00:00  -200.0         1011       1.3
# 11   2004-03-11 1900-01-01 05:00:00     0.7         1066       1.1
# 12   2004-03-11 1900-01-01 06:00:00     0.7         1052       1.6
# ...
